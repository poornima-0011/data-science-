# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading the dataset

# %%
df=pd.read_csv('auto-mpg.csv')

# %% [markdown]
# # Summarizing the dataset

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
print(df.shape)
print(df.ndim)
# Out:
# (398, 9)
# 2

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %% [markdown]
# ## checking for the duplicate values

# %%
df.duplicated().value_counts()
# Out:
# False    398
# Name: count, dtype: int64

# %% [markdown]
# ## No duplicate values found

# %% [markdown]
# ## Checking for missing values

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# ## Handling missing values

# %% [markdown]
# ## After Handling missing values

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Histogram for continous variable

# %%
    plt.hist(df['mpg'], bins=10, edgecolor='white')
# Out:
# (array([13., 78., 73., 61., 54., 48., 38., 22.,  5.,  6.]),
#  array([ 9.  , 12.76, 16.52, 20.28, 24.04, 27.8 , 31.56, 35.32, 39.08,
#         42.84, 46.6 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['displacement'], bins=10, edgecolor='white',color='green')
# Out:
# (array([107.,  89.,  31.,  13.,  57.,   3.,  42.,  31.,  16.,   9.]),
#  array([ 68. , 106.7, 145.4, 184.1, 222.8, 261.5, 300.2, 338.9, 377.6,
#         416.3, 455. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

sns.countplot(x='cylinders', data=df, palette='pastel')
plt.xlabel('Number of Cylinders')
plt.ylabel('Count')
plt.title('Count of Cars by Number of Cylinders')
plt.show()
# Out:
# /home/skanda/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/skanda/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/skanda/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## plotting the violin graph

# %%
sns.violinplot(y='mpg', data=df)
plt.ylabel('MPG')
plt.title('Distribution of MPG')
plt.show()
# Out:
# /home/skanda/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df['mpg'].value_counts()
# Out:
# mpg
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: count, Length: 129, dtype: int64

# %% [markdown]
# ## Measure of central tendency for MPG is relied between 15-33

# %%
sns.violinplot(y='acceleration', data=df)
plt.ylabel('acceleration')
plt.title('Distribution of Acceleration')
plt.show()
# Out:
# /home/skanda/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## More number of cars have the accelaration between 12.5 - 18

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(df['mpg'])
plt.title('Box Plot for MPG')

plt.subplot(1, 2, 2)
sns.boxplot(df['acceleration'])
plt.title('Box Plot for Acceleration')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Boxplot handling outliers

# %%
Q1_mpg = df['mpg'].quantile(0.25)
Q3_mpg = df['mpg'].quantile(0.75)
IQR_mpg = Q3_mpg - Q1_mpg

lower_bound_mpg = Q1_mpg - 1.5 * IQR_mpg
upper_bound_mpg = Q3_mpg + 1.5 * IQR_mpg

df = df[(df['mpg'] >= lower_bound_mpg) & (df['mpg'] <= upper_bound_mpg)]

# %%
Q1_acceleration = df['acceleration'].quantile(0.25)
Q3_acceleration = df['acceleration'].quantile(0.75)
IQR_acceleration = Q3_acceleration - Q1_acceleration
lower_bound_acceleration = Q1_acceleration - 1.5 * IQR_acceleration
upper_bound_acceleration = Q3_acceleration + 1.5 * IQR_acceleration

df = df[(df['acceleration'] >= lower_bound_acceleration) & (df['acceleration'] <= upper_bound_acceleration)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(df['mpg'])
plt.title('Box Plot for MPG')

plt.subplot(1, 2, 2)
sns.boxplot(df['acceleration'])
plt.title('Box Plot for Acceleration')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatmap

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean()).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 387 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           387 non-null    float64
#  1   cylinders     387 non-null    int64
#  2   displacement  387 non-null    float64
#  3   horsepower    387 non-null    int64
#  4   weight        387 non-null    int64
#  5   acceleration  387 non-null    float64
#  6   model year    387 non-null    int64
#  7   origin        387 non-null    int64
#  8   car name      387 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 38.3+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.drop('car name', axis=1).corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

numerical_columns = ['mpg', 'horsepower', 'weight', 'acceleration','displacement']

scaler = StandardScaler()

df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
df.head(10)
# Out:
# /home/skanda/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/skanda/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/skanda/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler(feature_range=(-1, 1))
df[numerical_columns] = min_max_scaler.fit_transform(df[numerical_columns])
df.head(10)
# Out:
# /home/skanda/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /home/skanda/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /home/skanda/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...
